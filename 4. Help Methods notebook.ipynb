# %% [markdown]
# # Help Methods
# <b>Notebook</b>

# %% [markdown]
# Let's start...

# %%
mylist = [1,2,3]

# %%
mylist.append(4)

# %%
mylist
# Out:
# [1, 2, 3, 4]

# %%
mylist.pop()
# Out:
# 4

# %%
mylist
# Out:
# [1, 2, 3]

# %% [markdown]
# then...
#
# # Methods inside Jupiter notebook
#
# <b>mylist.</b> and press <em>'tab'</em> to show functions avaible:

# %% [markdown]
# image:
#
# ![image.png](attachment:image.png)
#
# ____________

# %% [markdown]
# <b>mylist.insert </b> and press <em>'shift + tab'</em> to show explanation about the function:

# %% [markdown]
# image:
#
# ![image.png](attachment:image.png)
#
# __________________

# %% [markdown]
# <b>help(mylist.insert) </b> and press <em>'enter'</em> to see the explanation below</p>

# %%
help(mylist.insert)
# Out:
# Help on built-in function insert:
#
# insert(index, object, /) method of builtins.list instance
#     Insert object before index.

# %% [markdown]
# ___________________
#
# # Methods using external documentation
#
# go direct to <b>python documentation: </b> https://docs.python.org/3/
#
# or go to <b>stackoverflow<b/> to see better and simplest explanations https://stackoverflow.com/
# <p></p>
# <p></p>
# <p></p>

# %%
#try yourself here:

# %% [markdown]
# ___
# <font color='green' size='32'> End</br>
# <br>Well done!</br> </font>
